# %% [markdown]
# # 파이썬 코딩
# ## 첫 날
# ### 자료형
#
# - 정수
# - 실수
# - 문자열
# - 부울

# %%
print('hello world!')
# Out:
# hello world!

# %%
# shift + enter 키를 동시에 누르면 코드를 실행하고 아래에 빈 셀을 추가합니다.
print('hello world!')
# Out:
# hello world!

# %%
import requests

# %%
ticker = '005930'

# %%
# f-string은 문자열 안에 변수가 가리키는 값을 대입하는 것입니다.
url = f'https://finance.naver.com/item/main.naver?code={ticker}'
print(url)
# Out:
# https://finance.naver.com/item/main.naver?code=005930

# %%
# get 메서드에 정의된 url 매개변수에 방금 생성한 문자열 변수 url을 전달인수로 연결
res = requests.get(url = url)

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'date': 'Mon, 11 May 2026 04:13:21 GMT', 'cache-control': 'no-cache', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'set-cookie': 'JSESSIONID=EAD3BCC63163697C231751CB40EE272C; Path=/; HttpOnly', 'content-language': 'ko', 'vary': 'Accept-Encoding,User-Agent', 'content-encoding': 'gzip', 'referrer-policy': 'unsafe-url', 'transfer-encoding': 'chunked', 'content-type': 'text/html;charset=UTF-8', 'server': 'nfront', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'x-xss-protection': '1; mode=block'}

# %%
res.headers['content-type']
# Out:
# 'text/html;charset=UTF-8'

# %%
print(res.text)
# Out:
#
#
#
#
#
# <html lang='ko'>
# <head>
#
#
#
# 		<title>삼성전자 : Npay 증권</title>
#
#
#
#
#
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#
# <meta http-equiv="Content-Script-Type" content="text/javascript">
# <meta http-equiv="Content-Style-Type" content="text/css">
# <meta name="apple-mobile-web-app-title" content="Npay 증권" />
#
#
#
#
#
#
#
#         <meta property="og:url" content="https://finance.naver.com/item/main.naver?code=005930"/>
#
#
#
# 		    	<meta property="og:title" content="삼성전자 - Npay 증권 : Npay 증권"/>
#
#
#
#
# 			   <meta property="og:description" content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳"/>
#
#
#
#
#
# 			    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>
#
#
#
#
#
# <meta property="og:type" content="article"/>
# <meta property="og:article:thumbnailUrl" content=""/>
# <meta property="og:article:author" content="Npay 증권"/>
# ...

# %%
len(res.text)
# Out:
# 186682

# %%
print(res.url)
# Out:
# https://finance.naver.com/item/main.naver?code=005930

# %%
from bs4 import BeautifulSoup as BTS

# %%
soup = BTS(markup = res.text, features = 'html.parser')

# %%
items = soup.select(selector = 'div#rate_info_krx > div > p.no_today > em > span')
len(items)
# Out:
# 8

# %%
items
# Out:
# [<span class="blind">285,250</span>,
#  <span class="no2">2</span>,
#  <span class="no8">8</span>,
#  <span class="no5">5</span>,
#  <span class="shim">,</span>,
#  <span class="no2">2</span>,
#  <span class="no5">5</span>,
#  <span class="no0">0</span>]

# %%
items[0]
# Out:
# <span class="blind">285,250</span>

# %%
items[0].text
# Out:
# '285,250'

# %%
def stock_price(ticker):
    url = f'https://finance.naver.com/item/main.naver?code={ticker}'
    res = requests.get(url = url)
    soup = BTS(markup = res.text, features = 'html.parser')
    items = soup.select(selector = 'div#rate_info_krx > div > p.no_today > em > span')
    return items[0].text

# %%
stock_price(ticker = '005930')
# Out:
# '286,250'

# %%
stock_price(ticker = '000660')
# Out:
# '1,911,000'

# %%
tickers = ['005930', '000660', '402340', '005380', '373220']

# %%
import time

# %%
for ticker in tickers:
    price = stock_price(ticker)
    print(price)
    time.sleep(1)
# Out:
# 286,000
# 1,908,000
# 1,184,000
# 644,000
# 467,500

# %%
compNms = ['삼성전자', '하이닉스', 'SK스퀘어', '현대차', '엘지엔솔']

# %%
# zip 함수는 반복 가능한 객체의 같은 인덱스 원소를 튜플로 묶어서 반환합니다.
for i in zip(tickers, compNms):
    print(i)
# Out:
# ('005930', '삼성전자')
# ('000660', '하이닉스')
# ('402340', 'SK스퀘어')
# ('005380', '현대차')
# ('373220', '엘지엔솔')

# %%
for i, j in zip(tickers, compNms):
    print(j)
# Out:
# 삼성전자
# 하이닉스
# SK스퀘어
# 현대차
# 엘지엔솔

# %%
for ticker, compNm in zip(tickers, compNms):
    price = stock_price(ticker)
    print(f'{compNm}의 현재 가격은 {price}원입니다.')
    time.sleep(1)
# Out:
# 삼성전자의 현재 가격은 286,750원입니다.
# 하이닉스의 현재 가격은 1,918,000원입니다.
# SK스퀘어의 현재 가격은 1,198,000원입니다.
# 현대차의 현재 가격은 649,000원입니다.
# 엘지엔솔의 현재 가격은 468,500원입니다.
