# %%
'C:\Users\SDS\Documents\project\data'
# Out:
#   Cell In[1], line 1
#     'C:\Users\SDS\Documents\project\data'
#     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
'I am a boy'
# Out:
# 'I am a boy'

# %%
"I'm a boy"
# Out:
# "I'm a boy"

# %%
'I\'m a boy'
# Out:
# "I'm a boy"

# %%
'C:\\Users\\SDS\\Documents\\project\\data'
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\data'

# %%
'C:/Users/SDS/Documents/project/data'
# Out:
# 'C:/Users/SDS/Documents/project/data'

# %%
# raw string은 문자열 안의 이스케이프 기능을 일괄 해제
r'C:\Users\SDS\Documents\project\data'
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\data'

# %%
import os
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\code'

# %%
# 절대 경로 방식
os.chdir(path = 'C:\\Users\\SDS\\Documents\\project\\data')
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\data'

# %%
# 상대 경로 방식: '.'은 현재 폴더, '..'은 부모 폴더
os.chdir(path = '..')
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project'

# %%
# [참고] './'는 생략 가능
os.chdir(path = './code')
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\code'

# %%
# [주의] '../'는 생략 불가능
os.chdir(path = '../data')
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\data'

# %%
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx']

# %%
[file for file in os.listdir() if 'iris' in file]
# Out:
# ['iris.csv', 'iris.json', 'iris.parquet', 'iris.tsv', 'iris.xlsx']

# %%
[file for file in os.listdir() if '.csv' in file]
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv', 'iris.csv']

# %%
[file for file in os.listdir() if '2021' in file]
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx']

# %%
df1 = pd.read_excel('iris.xlsx')

# %%
# 함수 또는 객체의 메서드 괄호 안에 커서를 놓고 shift + tab 키를 동시에 누르면
# 해당 함수 또는 메서드의 설명서를 확인할 수 있습니다.
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1.to_excel('test.xlsx', index = False)

# %%
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx',
#  'test.xlsx']

# %%
df2 = pd.read_csv('iris.csv')
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df2.to_csv('test.csv', index = False)
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx',
#  'test.csv',
#  'test.xlsx']

# %%
# Python에서 텍스트 파일을 읽는 함수는 pd.read_csv() 하나로 충분!
df3 = pd.read_csv('iris.tsv', sep = '\t')
df3.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df3.to_csv('test.tsv', index = False, sep = '\t')
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx',
#  'test.csv',
#  'test.tsv',
#  'test.xlsx']

# %%
df4 = pd.read_json('iris.json')
df4.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df4.to_json('test.json')
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx',
#  'test.csv',
#  'test.json',
#  'test.tsv',
#  'test.xlsx']

# %%
df5 = pd.read_parquet('iris.parquet')
df5.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df5.to_parquet('test.parquet')
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx',
#  'test.csv',
#  'test.json',
#  'test.parquet',
#  'test.tsv',
#  'test.xlsx']

# %%
files = [file for file in os.listdir() if 'test' in file]
files
# Out:
# ['test.csv', 'test.json', 'test.parquet', 'test.tsv', 'test.xlsx']

# %%
for file in files:
    os.remove(file)

# %%
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx']
