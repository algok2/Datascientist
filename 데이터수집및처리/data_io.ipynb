# %%
import os
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\code'

# %%
os.chdir(path='C:\\Users\\SDS\\Documents\\project\\data')
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\data'

# %%
os.chdir(path='../code')
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\code'

# %%
os.chdir('../data')
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\data'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SDS\\Documents\\project\\data'

# %%
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx']

# %%
[file for file in os.listdir() if 'iris' in file]
# Out:
# ['iris.csv', 'iris.json', 'iris.parquet', 'iris.tsv', 'iris.xlsx']

# %%
df1 = pd.read_excel('iris.xlsx')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1.to_excel('test.xlsx')

# %%
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx',
#  'test.xlsx']

# %%
df2 = pd.read_csv('iris.csv')
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df2.to_csv('test.csv', index=False, )

# %%
df3 = pd.read_csv('iris.tsv', sep='\t')
df3.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df3.to_csv('test.tsv', index=False, sep='\t')
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv',
#  'APT_Price_Seoul_Merged_2021~2025.xlsx',
#  'Galaxy_Book_Review_20250131.xlsx',
#  'Galaxy_Book_Review_20250131_Corrected.xlsx',
#  'iris.csv',
#  'iris.json',
#  'iris.parquet',
#  'iris.tsv',
#  'iris.xlsx',
#  'test.csv',
#  'test.tsv',
#  'test.xlsx']

# %%
df4 = pd.read_json('iris.json')
df4.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from pprint import pprint

# %%
pprint(df4)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df4.to_json('test.json')
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv', 'APT_Price_Seoul_Merged_2021~2025.xlsx', 'Galaxy_Book_Review_20250131.xlsx', 'Galaxy_Book_Review_20250131_Corrected.xlsx', 'iris.csv', 'iris.json', 'iris.parquet', 'iris.tsv', 'iris.xlsx', 'test.csv', 'test.json', 'test.tsv', 'test.xlsx']

# %%
df5 = pd.read_parquet('iris.parquet')
df5.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df5.to_parquet('test.parquet')
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv', 'APT_Price_Seoul_Merged_2021~2025.xlsx', 'Galaxy_Book_Review_20250131.xlsx', 'Galaxy_Book_Review_20250131_Corrected.xlsx', 'iris.csv', 'iris.json', 'iris.parquet', 'iris.tsv', 'iris.xlsx', 'test.csv', 'test.json', 'test.parquet', 'test.tsv', 'test.xlsx']

# %%
files = [file for file in os.listdir() if 'test' in file ]

# %%
for file in files:
    os.remove(file)

# %%
os.listdir()
# Out:
# ['APT_Price_Seoul_Merged_2021~2025.csv', 'APT_Price_Seoul_Merged_2021~2025.xlsx', 'Galaxy_Book_Review_20250131.xlsx', 'Galaxy_Book_Review_20250131_Corrected.xlsx', 'iris.csv', 'iris.json', 'iris.parquet', 'iris.tsv', 'iris.xlsx']
