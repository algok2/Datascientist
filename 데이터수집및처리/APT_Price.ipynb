# %%
import requests

# %%
url = 'https://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade'

# %%
query = {
    'LAWD_CD': '11680', 
    'DEAL_YMD': '202605',
    'serviceKey': 'iBljZu7QtW9ki0qlRcuOTuNMPx+qAVk0/vo19Bq5xYmt80kkCkNi2TCyBX/hZhsxqKJtjbyBljpcksWCY6pKMA==',
    'pageNo': 1,
    'numOfRows': 10
}

# %%
res = requests.get(url= url, params=query)

# %%
res.status_code
# Out:
# 200

# %%
res.headers['content-type']
# Out:
# 'application/xml;charset=utf-8'

# %%
import xmltodict

# %%
dat = xmltodict.parse(res.text)

# %%
import pandas as pd

# %%
from pprint import pprint

# %%
pprint(dat)
# Out:
# {'response': {'body': {'items': {'item': [{'aptDong': None,
#                                            'aptNm': '세방하이빌1',
#                                            'buildYear': '2003',
#                                            'buyerGbn': '개인',
#                                            'cdealDay': None,
#                                            'cdealType': None,
#                                            'dealAmount': '134,000',
#                                            'dealDay': '7',
#                                            'dealMonth': '5',
#                                            'dealYear': '2026',
#                                            'dealingGbn': '중개거래',
#                                            'estateAgentSggNm': '서울 강남구',
#                                            'excluUseAr': '59.77',
#                                            'floor': '11',
#                                            'jibun': '771-4',
# ...

# %%
pd.DataFrame(data = dat['response']['body']['items']['item'] )
# Out:
#   aptDong      aptNm buildYear buyerGbn cdealDay cdealType dealAmount dealDay  \
# 0    None     세방하이빌1      2003       개인     None      None    134,000       7
# 1    None  개포자이프레지던스      2023       개인     None      None    360,000       5
# 2    None   쌍용플레티넘밸류      2007       개인     None      None    136,000       6
# 3    None        트레벨      2002       개인     None      None     50,100       4
# 4    None     역삼동하나빌      2002       개인     None      None     26,000       4
# 5    None   디에이치아너힐즈      2019       개인     None      None    217,000       1
# 6    None   삼성동한솔아파트      1998       개인     None      None    195,000       4
# 7    None      서광아파트      1998       개인     None      None    240,000       1
# 8    None      대우디오빌      2002       개인     None      None     76,000       4
# 9    None       까치마을      1993       개인     None      None    179,000       6
#
#   dealMonth dealYear dealingGbn estateAgentSggNm excluUseAr floor   jibun  \
# ...

# %%
# Out:
# [{'aptDong': None,
#   'aptNm': '세방하이빌1',
#   'buildYear': '2003',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '134,000',
#   'dealDay': '7',
#   'dealMonth': '5',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '서울 강남구',
#   'excluUseAr': '59.77',
#   'floor': '11',
#   'jibun': '771-4',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': None,
#   'sggCd': '11680',
#   'slerGbn': '개인',
#   'umdNm': '역삼동'},
#  {'aptDong': None,
#   'aptNm': '개포자이프레지던스',
#   'buildYear': '2023',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '360,000',
#   'dealDay': '5',
#   'dealMonth': '5',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '서울 강남구, 서울 송파구',
#   'excluUseAr': '84.5978',
#   'floor': '25',
#   'jibun': '1284',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': None,
#   'sggCd': '11680',
#   'slerGbn': '개인',
#   'umdNm': '개포동'},
#  {'aptDong': None,
# ...
